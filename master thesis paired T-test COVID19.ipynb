 0.0397,
0.1232,
0.1891,
0.1110,
0.4282]

# %%
p_value_1 = stats.ttest_rel(SVR_MAE_model, LSTM_MAE_model)
p_value_2 = stats.ttest_rel(SVR_MAE_model, GRU_MAE_model)
p_value_3 = stats.ttest_rel(LSTM_MAE_model, GRU_MAE_model)
p_value_4 = stats.ttest_rel(SVR_MAE_model, BI_LSTM_mae_model)
p_value_5 = stats.ttest_rel(SVR_MAE_model, LSTM_CNN_mae_model)
p_value_6 = stats.ttest_rel(LSTM_MAE_model, BI_LSTM_mae_model)
p_value_7 = stats.ttest_rel(LSTM_MAE_model, LSTM_CNN_mae_model)
p_value_8 = stats.ttest_rel(GRU_MAE_model, BI_LSTM_mae_model)
p_value_9 = stats.ttest_rel(GRU_MAE_model, LSTM_CNN_mae_model)
p_value_10 = stats.ttest_rel(BI_LSTM_mae_model, LSTM_CNN_mae_model)

# %%
print("-----Models------")
print("SVR VS LSTM",p_value_1)
print("SVR VS GRU",p_value_2)
print("LSTM VS GRU",p_value_3)
print("SVR VS BI-LSTM",p_value_4)
print("SVR VS LSTM-CNN",p_value_5)
print("LSTM VS BI-LSTM",p_value_6)
print("LSTM VS LSTM-CNN",p_value_7)
print("GRU VS BI-LSTM",p_value_8)
print("GRU VS LSTM-CNN",p_value_9)
print("BI-LSTM VS LSTM-CNN",p_value_10)
# Out:
# -----Models------
# SVR VS LSTM Ttest_relResult(statistic=-1.5179929194984763, pvalue=0.13751522287873255)
# SVR VS GRU Ttest_relResult(statistic=-0.47327433289934073, pvalue=0.6387979052303596)
# LSTM VS GRU Ttest_relResult(statistic=1.6910410904460915, pvalue=0.09923720211806789)
# SVR VS BI-LSTM Ttest_relResult(statistic=-0.49242685189273044, pvalue=0.6253270572862264)
# SVR VS LSTM-CNN Ttest_relResult(statistic=1.7346503131180153, pvalue=0.09112758972483512)
# LSTM VS BI-LSTM Ttest_relResult(statistic=0.9818111270108407, pvalue=0.33256960364064647)
# LSTM VS LSTM-CNN Ttest_relResult(statistic=5.753887040097657, pvalue=1.35285098701583e-06)
# GRU VS BI-LSTM Ttest_relResult(statistic=-0.23340462684869934, pvalue=0.8167337463333277)
# GRU VS LSTM-CNN Ttest_relResult(statistic=3.2701562906130293, pvalue=0.002328877756049634)
# BI-LSTM VS LSTM-CNN Ttest_relResult(statistic=3.3544750001869263, pvalue=0.0018470174480174372)

# %%
print(len(SVR_MAE_model))
print(len(LSTM_MAE_model))
print(len(GRU_MAE_model))
# Out:
# 38
# 38
# 38
